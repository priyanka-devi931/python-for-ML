# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  0.263654 -0.403994 -0.136790
# b       NaN       NaN       NaN
# c  0.810168 -1.869425 -2.021258
# d -0.758177  2.397685 -0.964185
# e       NaN       NaN       NaN
# f  0.441737  0.540419 -1.445581
#
#
# Dropped DataFrame
#          one       two     three
# a  0.263654 -0.403994 -0.136790
# c  0.810168 -1.869425 -2.021258
# d -0.758177  2.397685 -0.964185
# f  0.441737  0.540419 -1.445581

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.921622  1.447462  0.142614
# b       NaN       NaN       NaN
# c -0.052989  1.720336  0.012610
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -0.921622  1.447462  0.142614
# b  0.000000  0.000000  0.000000
# c -0.052989  1.720336  0.012610

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a -1.718777 -0.694776  0.116883
# b       NaN       NaN       NaN
# c  1.305078 -1.064696  0.920604
# d  1.034151 -0.528536  0.480487
# e       NaN       NaN       NaN
# f  0.039660  1.435718  1.279499
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a -1.281272  1.419761 -1.127931
# b       NaN       NaN       NaN
# c -1.624548  0.747752 -1.245500
# d -1.687704 -0.897269  0.379619
# e       NaN       NaN       NaN
# f -1.046380  0.506376 -0.736657
#
# NaN - Filled with Background values:
#
#         one       two     three
# a -1.281272  1.419761 -1.127931
# b -1.624548  0.747752 -1.245500
# c -1.624548  0.747752 -1.245500
# d -1.687704 -0.897269  0.379619
# e -1.046380  0.506376 -0.736657
# f -1.046380  0.506376 -0.736657
# /tmp/ipykernel_323/4216389697.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
